# %% [markdown]
# <a href="https://colab.research.google.com/github/RishabhXYZA/MIni-Project-3-Subset-Selection-Problem/blob/main/Subset_Selection_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Subset problem
#Find all the subsets from a set of numbers whose sum is zero.
#Constraint: Subset size must be 5
Set=[-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4]
length=len(Set)
count=0
for i in range(length):
    for j in range(i+1,length):
        for k in range(j+1,length):
            for l in range(k+1,length):
                for m in range(l+1,length):
                    subset=[Set[i],Set[j],Set[k],Set[l],Set[m]]
                    if sum(subset)==0:
                        count+=1
                        print(set(subset))
print("Total Subsets -->",count)
# Out:
# {2, 6, 7, -12, -3}
# {6, 11, -12, -3, -2}
# {1, 3, 11, -12, -3}
# {9, 11, -12, -5, -3}
# {2, 7, 9, -12, -6}
# {9, 11, -12, -6, -2}
# {3, 6, 9, -12, -6}
# {1, 6, 11, -12, -6}
# {2, 7, 11, -12, -8}
# {1, 6, 7, -12, -2}
# {7, 11, -12, -4, -2}
# {3, 6, 7, -12, -4}
# {3, 7, 9, -12, -7}
# {3, 7, 11, -12, -9}
# {1, 7, 9, -12, -5}
# {1, 7, 11, -12, -7}
# {2, 3, 9, -12, -2}
# {1, 2, 11, -12, -2}
# {1, 2, 3, 6, -12}
# {2, 6, 9, -12, -5}
# {2, 6, 11, -12, -7}
# {2, 3, 11, -12, -4}
# {3, 6, 11, -12, -8}
# {1, 6, 9, -12, -4}
# {1, 9, 11, -12, -9}
# {6, 7, -6, -4, -3}
# {7, 9, -7, -6, -3}
# {7, 11, -9, -6, -3}
# {2, 9, -6, -3, -2}
# {1, 2, 6, -6, -3}
# {2, 11, -6, -4, -3}
# {6, 11, -8, -6, -3}
# {3, 11, -6, -5, -3}
# {2, 7, -4, -3, -2}
# {2, 3, 7, -9, -3}
# {1, 2, 7, -7, -3}
# {6, 7, -8, -3, -2}
# {3, 7, -5, -3, -2}
# {1, 3, 7, -8, -3}
# {7, 9, -8, -5, -3}
# {7, 9, -9, -4, -3}
# {7, 11, -8, -7, -3}
# {2, 11, -8, -3, -2}
# {2, 3, 6, -8, -3}
# {1, 2, 9, -9, -3}
# {3, 6, -4, -3, -2}
# ...

# %%
Set=[-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4]
length=len(Set)
count1=0  #for size of subset 3
count2=0  #for size of subset 6


for i in range(length):
    for j in range(i+1,length):
        for k in range(j+1,length):
            subset=[Set[i],Set[j],Set[k]]
            if sum(subset)==0:
                count1+=1
                print(set(subset))


for i in range(length):
    for j in range(i+1,length):
        for k in range(j+1,length):
            for l in range(k+1,length):
                for m in range(l+1,length):
                    for n in range(m+1,length):
                        subset=[Set[i],Set[j],Set[k],Set[l],Set[m],Set[n]]
                        if sum(subset)==0:
                            count2+=1
                            print(set(subset))

print("\n")
print("Total subsets of size 3 -->",count1)
print("Total Subsets of size 6 -->",count2)
count3=count1+count2
print("\n")
print("Totak Subsets are -->",count3)
# Out:
# {9, 3, -12}
# {1, 11, -12}
# {9, -6, -3}
# {-4, -3, 7}
# {1, 2, -3}
# {-8, 11, -3}
# {11, -6, -5}
# {2, -9, 7}
# {-5, -2, 7}
# {-8, 1, 7}
# {-8, 2, 6}
# {2, 3, -5}
# {-4, -2, 6}
# {9, -7, -2}
# {11, -2, -9}
# {3, 6, -9}
# {-7, 6, 1}
# {1, 3, -4}
# {9, -5, -4}
# {-7, 11, -4}
# {3, 7, 11, -12, -6, -3}
# {1, 9, 11, -12, -6, -3}
# {2, 7, 11, -12, -5, -3}
# {1, 7, 9, -12, -3, -2}
# {6, 7, 9, -12, -7, -3}
# {6, 7, 11, -12, -9, -3}
# {3, 7, 9, -12, -4, -3}
# {1, 7, 11, -12, -4, -3}
# {2, 6, 9, -12, -3, -2}
# {2, 6, 11, -12, -4, -3}
# {1, 2, 3, 9, -12, -3}
# {2, 9, 11, -12, -7, -3}
# {3, 6, 11, -12, -5, -3}
# {3, 9, 11, -12, -8, -3}
# {2, 7, 11, -12, -6, -2}
# {2, 3, 6, 7, -12, -6}
# {6, 7, 9, -12, -6, -4}
# {7, 9, 11, -12, -9, -6}
# {1, 2, 6, 9, -12, -6}
# {2, 9, 11, -12, -6, -4}
# {3, 6, 11, -12, -6, -2}
# {6, 9, 11, -12, -8, -6}
# {3, 9, 11, -12, -6, -5}
# {2, 7, 9, -12, -4, -2}
# {1, 2, 6, 7, -12, -4}
# {2, 3, 7, 9, -12, -9}
# {1, 2, 7, 9, -12, -7}
# {1, 2, 7, 11, -12, -9}
# ...
